# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import torch.nn as nn
from torch.distributions.kl import kl_divergence

# %%
def f(x, alpha):
    return np.sin(alpha*x)

#data generator - 
num_curves = 2000
points_per_curve = 50
x_range = [-2, 2]
alpha_range = [-1, 1]

data = []
xspace = torch.linspace(x_range[0], x_range[1], points_per_curve)
for i in range(num_curves):
    alpha = np.random.uniform(alpha_range[0], alpha_range[1])
    data.append([xspace, f(xspace, alpha)])

num_plots = 20
for i in range(num_plots):
    function = data[i]
    plt.plot(function[0].numpy(), function[1].numpy())
    
def test_f(x):
    return np.sin(x)

testspace = torch.linspace(-2, 2, 4)
test_data = [testspace, test_f(testspace)]

# %%
class encoder(nn.Module):
    def __init__(self, output_sizes):
        super(encoder, self).__init__()
        self.output_sizes = output_sizes
        
        self.fc1 = nn.Linear(2, 10)
        self.fc2 = nn.Linear(10, 10)
        self.fc3_sigma = nn.Linear(10, self.output_sizes)
        self.fc3_mu = nn.Linear(10, self.output_sizes)
        self.relu = nn.ReLU()
        
    def forward(self, x, y):
        #x and y are 1xn dimensional torch tensors
        
        xy = torch.cat([x, y], dim=0).transpose(0, 1)
        l1 = self.relu(self.fc1(xy))
        l2 = self.relu(self.fc2(l1))
        logvar = self.fc3_sigma(l2)
        mu = self.fc3_mu(l2)
        sigma = torch.exp(logvar.mul(1/2))
        
        out_mu = torch.mean(mu, dim=0)
        out_sigma = torch.mean(sigma, dim=0)
        
        print(out_mu.reshape(self.output_sizes, 1), out_sigma.reshape(self.output_sizes, 1))
        print(torch.distributions.Normal(out_mu, out_sigma))
        
        return out_mu.reshape(self.output_sizes, 1), out_sigma.reshape(self.output_sizes, 1), torch.distributions.Normal(out_mu, out_sigma)

# %%
class decoder(nn.Module):
    def __init__(self, encoded_size):
        super(decoder, self).__init__()
        self.encoded_size = encoded_size
        
        self.fc1 = nn.Linear(self.encoded_size + 1, 10)
        self.fc2 = nn.Linear(10, 10)
        self.fc21 = nn.Linear(10, 10)
        self.fc3_mu = nn.Linear(10, 1)
        self.fc3_sigma = nn.Linear(10, 1)
        self.relu = nn.ReLU()
        
    def forward(self, z, x):
        #x and z are 1xn dimensional torch tensors
        
        zmulti = torch.cat([z for i in range(x.size()[1])], dim=1)
        xz = torch.cat([x, zmulti]).transpose(0, 1)
        
        l1 = self.relu(self.fc1(xz))
        l2 = self.relu(self.fc2(l1))
        l21 = self.relu(self.fc21(l2))
        out_mu = self.fc3_mu(l21)
        out_logvar = self.fc3_sigma(l21)
        out_sigma = torch.exp(out_logvar.mul(1/2))
        
        dist = torch.distributions.Normal(out_mu, out_sigma)
        
        return out_mu, out_sigma, dist

# %%
class r_to_z(nn.Module):
    def __init__(self, encoded_size):
        super(r_to_z, self).__init__()
        self.encoded_size = encoded_size

# %%
class CNP(nn.Module):
    def __init__(self, encoded_size):
        super(CNP, self).__init__()
        self.encoded_size = encoded_size
        self._encoder = encoder(encoded_size)
        self._decoder = decoder(encoded_size)
        
    def forward(self, context_x, context_y, target_x, target_y=None):
        en_mu, en_sigma, en_dist = self._encoder(context_x, context_y)
        if target_y is not None:
            t_en_mu, t_en_sigma, t_en_dist = self._encoder(target_x, target_y)
            representation = t_en_dist.rsample().unsqueeze(0).transpose(0,1)
        else:
            representation = en_dist.rsample().unsqueeze(0).transpose(0, 1)
            t_en_dist = None

        mu, sigma, dist = self._decoder(representation, target_x)
        
        if target_y is not None:
            log_p = dist.log_prob(target_y.transpose(0, 1)).sum()
            MSE = (mu - target_y.transpose(0,1)).sum()
        else:
            log_p = None
            MSE = None
        return mu, sigma, log_p, en_dist, t_en_dist

# %%
cnp = CNP(3)
optimizer = torch.optim.Adam(cnp.parameters(), lr=1e-3)
num_test_maximum = 40
plot_frequency = 1
alpha = torch.tensor(1)

def compute_kernel(x, y):
    return (-(x - y).pow(2)).exp()

def MMD(z_prior, z_posterior, num_samples):
    target_samples_1 = z_prior.sample((num_samples,))
    context_samples_1 = z_posterior.sample((num_samples,))
    target_samples_2 = z_prior.sample((num_samples,))
    context_samples_2 = z_posterior.sample((num_samples,))
    
    t_kernel = compute_kernel(target_samples_1, target_samples_2)
    c_kernel = compute_kernel(context_samples_1, context_samples_2)
    ct_kernel = compute_kernel(target_samples_1, context_samples_1) + compute_kernel(target_samples_2, context_samples_2)
    return (t_kernel + c_kernel - ct_kernel).mean()
    

def lossf(log_p, z_prior, context_z_posterior, test_z_posterior, alpha):
    KL =  MMD(test_z_posterior, context_z_posterior, 10).prod()
    return -log_p + alpha*KL


def train(data, cnp, epochs, test_data):
    for epoch in range(epochs):
        total_loss = 0
        iteration = 0
        for function in data:
            optimizer.zero_grad()
            num_points = function[0].size()[0]
            perm = torch.randperm(num_points)
            num_context = np.random.randint(num_points - num_test_maximum, num_points)
            context_x = function[0][perm][0:num_context].unsqueeze(0)
            context_y = function[1][perm][0:num_context].unsqueeze(0)
            test_x = function[0][perm][num_context:num_points].unsqueeze(0)
            test_y = function[1][perm][num_context:num_points].unsqueeze(0)
            
            mu, sigma, log_p, en_dist, t_en_dist = cnp(context_x, context_y, test_x, test_y)
            loss = lossf(log_p, torch.distributions.Normal(torch.zeros(cnp.encoded_size), 1), en_dist, t_en_dist, alpha)
            loss.backward()
            optimizer.step()
            
            total_loss += loss
            iteration += 1
            
            if iteration % 200 == 0:
                print(iteration)
        
        if epoch % plot_frequency == 0:
            print("EPOCH: {}, LOSS {}".format(epoch, total_loss))
            test_x = test_data[0].unsqueeze(0)
            test_y = test_data[1].unsqueeze(0)
            
            linspace = torch.linspace(-2, 2, 100).unsqueeze(0)
            mu, sigma, _, _, _ = cnp(test_x, test_y, linspace)
            lin = (linspace.numpy()[0])
            low = np.array((mu-sigma).detach().numpy().T[0])
            high = np.array((mu+sigma).detach().numpy().T[0])
            plt.plot(linspace.numpy()[0], mu.detach().numpy())
            plt.fill_between(lin, low, high, facecolor='#65c9f7', interpolate=True)
            plt.scatter(test_x.numpy(), test_y.numpy(), c='black')
            plt.show()
            
            plt.plot(linspace.numpy()[0], sigma.detach().numpy())
            plt.show()

            
def plot_priors(np, number):
    norm = torch.distributions.Normal(torch.zeros(np.encoded_size), 1)
    for i in range(number):
        z = norm.rsample().unsqueeze(0).transpose(0, 1)
        lin = torch.linspace(-2, 2, 100).unsqueeze(0)
        ys, _, _ = np._decoder(z, lin)
        yplot = ys.transpose(0,1).squeeze(0).detach().numpy()
        xplot = lin.squeeze(0).numpy()
        plt.plot(xplot, yplot)

# %%
plot_priors(cnp, 10)

# %%
train(data, cnp, 15, test_data)
# Out:
# tensor([[ 0.0973],
#         [ 0.0414],
#         [-0.3615]], grad_fn=<AsStridedBackward>) tensor([[0.9778],
#         [1.0308],
#         [0.9941]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0862],
#         [ 0.0371],
#         [-0.3684]], grad_fn=<AsStridedBackward>) tensor([[0.9758],
#         [1.0232],
#         [0.9922]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0945],
#         [ 0.0331],
#         [-0.3228]], grad_fn=<AsStridedBackward>) tensor([[0.9706],
#         [1.0508],
#         [0.9987]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0980],
#         [ 0.0329],
#         [-0.3458]], grad_fn=<AsStridedBackward>) tensor([[0.9740],
#         [1.0466],
#         [0.9955]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0887],
#         [ 0.0304],
#         [-0.3341]], grad_fn=<AsStridedBackward>) tensor([[0.9709],
#         [1.0608],
#         [1.0002]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0900],
#         [ 0.0261],
#         [-0.3406]], grad_fn=<AsStridedBackward>) tensor([[0.9729],
#         [1.0598],
#         [1.0019]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0913],
#         [ 0.0261],
#         [-0.3621]], grad_fn=<AsStridedBackward>) tensor([[0.9705],
#         [1.0577],
#         [0.9951]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0895],
#         [ 0.0240],
#         [-0.3314]], grad_fn=<AsStridedBackward>) tensor([[0.9709],
#         [1.0565],
#         [1.0024]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0424],
#         [-0.0223],
#         [-0.4157]], grad_fn=<AsStridedBackward>) tensor([[0.9826],
#         [1.0357],
#         [1.0082]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0610],
#         [ 0.0016],
#         [-0.4103]], grad_fn=<AsStridedBackward>) tensor([[0.9864],
#         [1.0446],
#         [1.0056]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0887],
#         [ 0.0159],
#         [-0.3453]], grad_fn=<AsStridedBackward>) tensor([[0.9658],
#         [1.0457],
#         [0.9976]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0951],
#         [ 0.0208],
#         [-0.3364]], grad_fn=<AsStridedBackward>) tensor([[0.9692],
#         [1.0405],
#         [0.9986]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0583],
#         [-0.0133],
#         [-0.4080]], grad_fn=<AsStridedBackward>) tensor([[0.9812],
#         [1.0356],
#         [1.0049]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0548],
#         [-0.0095],
#         [-0.4065]], grad_fn=<AsStridedBackward>) tensor([[0.9834],
#         [1.0381],
#         [1.0064]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0899],
#         [ 0.0138],
#         [-0.3653]], grad_fn=<AsStridedBackward>) tensor([[0.9707],
#         [1.0220],
#         [0.9951]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0854],
#         [ 0.0095],
#         [-0.3605]], grad_fn=<AsStridedBackward>) tensor([[0.9685],
#         [1.0286],
#         [0.9957]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0854],
#         [ 0.0071],
#         [-0.3270]], grad_fn=<AsStridedBackward>) tensor([[0.9627],
#         [1.0413],
#         [0.9981]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0907],
#         [ 0.0069],
#         [-0.3433]], grad_fn=<AsStridedBackward>) tensor([[0.9654],
#         [1.0378],
#         [0.9977]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0902],
#         [ 0.0072],
#         [-0.3408]], grad_fn=<AsStridedBackward>) tensor([[0.9627],
#         [1.0272],
#         [0.9941]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0930],
#         [ 0.0029],
#         [-0.3503]], grad_fn=<AsStridedBackward>) tensor([[0.9650],
#         [1.0241],
#         [0.9942]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 8.8097e-02],
#         [-2.6287e-04],
#         [-3.2854e-01]], grad_fn=<AsStridedBackward>) tensor([[0.9631],
#         [1.0390],
#         [1.0006]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0872],
#         [ 0.0012],
#         [-0.3429]], grad_fn=<AsStridedBackward>) tensor([[0.9623],
#         [1.0329],
#         [0.9951]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0820],
#         [-0.0031],
#         [-0.3353]], grad_fn=<AsStridedBackward>) tensor([[0.9613],
#         [1.0448],
#         [0.9981]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0827],
#         [-0.0068],
#         [-0.3356]], grad_fn=<AsStridedBackward>) tensor([[0.9641],
#         [1.0464],
#         [1.0032]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0801],
#         [-0.0087],
#         [-0.3327]], grad_fn=<AsStridedBackward>) tensor([[0.9623],
#         [1.0494],
#         [1.0022]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0785],
#         [-0.0097],
#         [-0.3362]], grad_fn=<AsStridedBackward>) tensor([[0.9628],
#         [1.0511],
#         [1.0039]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0811],
#         [-0.0044],
#         [-0.3119]], grad_fn=<AsStridedBackward>) tensor([[0.9593],
#         [1.0423],
#         [1.0016]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0816],
#         [-0.0158],
#         [-0.3582]], grad_fn=<AsStridedBackward>) tensor([[0.9625],
#         [1.0384],
#         [0.9978]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0523],
#         [-0.0278],
#         [-0.3757]], grad_fn=<AsStridedBackward>) tensor([[0.9648],
#         [1.0234],
#         [0.9992]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0782],
#         [-0.0120],
#         [-0.3715]], grad_fn=<AsStridedBackward>) tensor([[0.9686],
#         [1.0251],
#         [0.9980]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0363],
#         [-0.0513],
#         [-0.4012]], grad_fn=<AsStridedBackward>) tensor([[0.9716],
#         [1.0297],
#         [1.0076]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0486],
#         [-0.0362],
#         [-0.4019]], grad_fn=<AsStridedBackward>) tensor([[0.9738],
#         [1.0377],
#         [1.0052]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0786],
#         [-0.0182],
#         [-0.3342]], grad_fn=<AsStridedBackward>) tensor([[0.9576],
#         [1.0346],
#         [0.9976]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.1025],
#         [ 0.0113],
#         [-0.3228]], grad_fn=<AsStridedBackward>) tensor([[0.9691],
#         [1.0332],
#         [1.0061]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0657],
#         [-0.0286],
#         [-0.3447]], grad_fn=<AsStridedBackward>) tensor([[0.9566],
#         [1.0627],
#         [1.0057]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0751],
#         [-0.0154],
#         [-0.3241]], grad_fn=<AsStridedBackward>) tensor([[0.9600],
#         [1.0495],
#         [1.0050]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0755],
#         [-0.0234],
#         [-0.3325]], grad_fn=<AsStridedBackward>) tensor([[0.9583],
#         [1.0412],
#         [1.0010]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0707],
#         [-0.0192],
#         [-0.3351]], grad_fn=<AsStridedBackward>) tensor([[0.9535],
#         [1.0407],
#         [0.9947]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0802],
#         [-0.0239],
#         [-0.3239]], grad_fn=<AsStridedBackward>) tensor([[0.9539],
#         [1.0284],
#         [0.9956]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0790],
#         [-0.0210],
#         [-0.3450]], grad_fn=<AsStridedBackward>) tensor([[0.9567],
#         [1.0200],
#         [0.9928]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0696],
#         [-0.0282],
#         [-0.3457]], grad_fn=<AsStridedBackward>) tensor([[0.9574],
#         [1.0526],
#         [1.0021]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0701],
#         [-0.0241],
#         [-0.3092]], grad_fn=<AsStridedBackward>) tensor([[0.9580],
#         [1.0481],
#         [1.0067]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0326],
#         [-0.0517],
#         [-0.4086]], grad_fn=<AsStridedBackward>) tensor([[0.9708],
#         [1.0406],
#         [1.0049]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0348],
#         [-0.0604],
#         [-0.4008]], grad_fn=<AsStridedBackward>) tensor([[0.9677],
#         [1.0243],
#         [1.0048]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0336],
#         [-0.0594],
#         [-0.3985]], grad_fn=<AsStridedBackward>) tensor([[0.9672],
#         [1.0249],
#         [1.0038]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0499],
#         [-0.0414],
#         [-0.3991]], grad_fn=<AsStridedBackward>) tensor([[0.9691],
#         [1.0378],
#         [1.0003]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0269],
#         [-0.0647],
#         [-0.4034]], grad_fn=<AsStridedBackward>) tensor([[0.9673],
#         [1.0283],
#         [1.0052]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0740],
#         [-0.0172],
#         [-0.4070]], grad_fn=<AsStridedBackward>) tensor([[0.9725],
#         [1.0511],
#         [0.9955]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0655],
#         [-0.0411],
#         [-0.3208]], grad_fn=<AsStridedBackward>) tensor([[0.9578],
#         [1.0464],
#         [1.0061]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0647],
#         [-0.0315],
#         [-0.3408]], grad_fn=<AsStridedBackward>) tensor([[0.9551],
#         [1.0542],
#         [1.0028]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0459],
#         [-0.0487],
#         [-0.3927]], grad_fn=<AsStridedBackward>) tensor([[0.9662],
#         [1.0291],
#         [0.9994]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0331],
#         [-0.0665],
#         [-0.3905]], grad_fn=<AsStridedBackward>) tensor([[0.9632],
#         [1.0152],
#         [1.0011]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0723],
#         [-0.0327],
#         [-0.3521]], grad_fn=<AsStridedBackward>) tensor([[0.9564],
#         [1.0186],
#         [0.9924]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0616],
#         [-0.0455],
#         [-0.3436]], grad_fn=<AsStridedBackward>) tensor([[0.9504],
#         [1.0211],
#         [0.9917]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0731],
#         [-0.0339],
#         [-0.3369]], grad_fn=<AsStridedBackward>) tensor([[0.9533],
#         [1.0239],
#         [0.9936]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0583],
#         [-0.0521],
#         [-0.3483]], grad_fn=<AsStridedBackward>) tensor([[0.9473],
#         [1.0154],
#         [0.9885]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0480],
#         [-0.0593],
#         [-0.3664]], grad_fn=<AsStridedBackward>) tensor([[0.9525],
#         [1.0113],
#         [0.9925]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0713],
#         [-0.0288],
#         [-0.3565]], grad_fn=<AsStridedBackward>) tensor([[0.9596],
#         [1.0282],
#         [0.9938]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0426],
#         [-0.0606],
#         [-0.3836]], grad_fn=<AsStridedBackward>) tensor([[0.9606],
#         [1.0161],
#         [0.9969]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0475],
#         [-0.0484],
#         [-0.3857]], grad_fn=<AsStridedBackward>) tensor([[0.9631],
#         [1.0295],
#         [0.9969]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0367],
#         [-0.0622],
#         [-0.3976]], grad_fn=<AsStridedBackward>) tensor([[0.9644],
#         [1.0273],
#         [0.9999]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0174],
#         [-0.0781],
#         [-0.4029]], grad_fn=<AsStridedBackward>) tensor([[0.9629],
#         [1.0279],
#         [1.0024]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0546],
#         [-0.0510],
#         [-0.3646]], grad_fn=<AsStridedBackward>) tensor([[0.9545],
#         [1.0164],
#         [0.9919]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0586],
#         [-0.0484],
#         [-0.3625]], grad_fn=<AsStridedBackward>) tensor([[0.9555],
#         [1.0197],
#         [0.9921]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0270],
#         [-0.1297],
#         [-0.4063]], grad_fn=<AsStridedBackward>) tensor([[0.9560],
#         [1.0017],
#         [1.0103]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0419],
#         [-0.0506],
#         [-0.4074]], grad_fn=<AsStridedBackward>) tensor([[0.9679],
#         [1.0403],
#         [0.9968]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0318],
#         [-0.0747],
#         [-0.3898]], grad_fn=<AsStridedBackward>) tensor([[0.9594],
#         [1.0109],
#         [0.9957]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0449],
#         [-0.0463],
#         [-0.3929]], grad_fn=<AsStridedBackward>) tensor([[0.9659],
#         [1.0376],
#         [0.9945]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0354],
#         [-0.0685],
#         [-0.3789]], grad_fn=<AsStridedBackward>) tensor([[0.9563],
#         [1.0108],
#         [0.9920]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0578],
#         [-0.0422],
#         [-0.3777]], grad_fn=<AsStridedBackward>) tensor([[0.9614],
#         [1.0291],
#         [0.9915]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0678],
#         [-0.0294],
#         [-0.3081]], grad_fn=<AsStridedBackward>) tensor([[0.9534],
#         [1.0313],
#         [0.9934]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0565],
#         [-0.0579],
#         [-0.3453]], grad_fn=<AsStridedBackward>) tensor([[0.9521],
#         [1.0414],
#         [0.9959]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0610],
#         [-0.0493],
#         [-0.3373]], grad_fn=<AsStridedBackward>) tensor([[0.9514],
#         [1.0295],
#         [0.9907]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0593],
#         [-0.0599],
#         [-0.3395]], grad_fn=<AsStridedBackward>) tensor([[0.9503],
#         [1.0337],
#         [0.9935]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0116],
#         [-0.1102],
#         [-0.4090]], grad_fn=<AsStridedBackward>) tensor([[0.9595],
#         [1.0115],
#         [1.0013]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0235],
#         [-0.0703],
#         [-0.4086]], grad_fn=<AsStridedBackward>) tensor([[0.9646],
#         [1.0331],
#         [0.9940]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0599],
#         [-0.0553],
#         [-0.3402]], grad_fn=<AsStridedBackward>) tensor([[0.9505],
#         [1.0260],
#         [0.9885]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0620],
#         [-0.0480],
#         [-0.3427]], grad_fn=<AsStridedBackward>) tensor([[0.9501],
#         [1.0221],
#         [0.9862]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0537],
#         [-0.0579],
#         [-0.3507]], grad_fn=<AsStridedBackward>) tensor([[0.9529],
#         [1.0477],
#         [0.9942]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0580],
#         [-0.0508],
#         [-0.3281]], grad_fn=<AsStridedBackward>) tensor([[0.9531],
#         [1.0436],
#         [0.9953]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0642],
#         [-0.0442],
#         [-0.3396]], grad_fn=<AsStridedBackward>) tensor([[0.9527],
#         [1.0263],
#         [0.9882]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0462],
#         [-0.0776],
#         [-0.3456]], grad_fn=<AsStridedBackward>) tensor([[0.9470],
#         [1.0326],
#         [0.9882]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0057],
#         [-0.0868],
#         [-0.4096]], grad_fn=<AsStridedBackward>) tensor([[0.9624],
#         [1.0234],
#         [0.9940]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0243],
#         [-0.0677],
#         [-0.4162]], grad_fn=<AsStridedBackward>) tensor([[0.9651],
#         [1.0381],
#         [0.9894]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0543],
#         [-0.0610],
#         [-0.3419]], grad_fn=<AsStridedBackward>) tensor([[0.9506],
#         [1.0324],
#         [0.9888]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0983],
#         [-0.0201],
#         [-0.3761]], grad_fn=<AsStridedBackward>) tensor([[0.9696],
#         [1.0050],
#         [0.9830]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0558],
#         [-0.0593],
#         [-0.3464]], grad_fn=<AsStridedBackward>) tensor([[0.9503],
#         [1.0244],
#         [0.9855]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0571],
#         [-0.0599],
#         [-0.3433]], grad_fn=<AsStridedBackward>) tensor([[0.9498],
#         [1.0238],
#         [0.9851]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0009],
#         [-0.0895],
#         [-0.4165]], grad_fn=<AsStridedBackward>) tensor([[0.9624],
#         [1.0271],
#         [0.9916]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0115],
#         [-0.0795],
#         [-0.4127]], grad_fn=<AsStridedBackward>) tensor([[0.9638],
#         [1.0285],
#         [0.9906]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0497],
#         [-0.0688],
#         [-0.3528]], grad_fn=<AsStridedBackward>) tensor([[0.9489],
#         [1.0234],
#         [0.9841]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0646],
#         [-0.0485],
#         [-0.3345]], grad_fn=<AsStridedBackward>) tensor([[0.9519],
#         [1.0232],
#         [0.9856]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0367],
#         [-0.0640],
#         [-0.3903]], grad_fn=<AsStridedBackward>) tensor([[0.9593],
#         [1.0234],
#         [0.9845]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0171],
#         [-0.0841],
#         [-0.3927]], grad_fn=<AsStridedBackward>) tensor([[0.9566],
#         [1.0070],
#         [0.9848]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0481],
#         [-0.0663],
#         [-0.3593]], grad_fn=<AsStridedBackward>) tensor([[0.9527],
#         [1.0476],
#         [0.9916]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0507],
#         [-0.0624],
#         [-0.3211]], grad_fn=<AsStridedBackward>) tensor([[0.9517],
#         [1.0439],
#         [0.9939]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0479],
#         [-0.0685],
#         [-0.3498]], grad_fn=<AsStridedBackward>) tensor([[0.9521],
#         [1.0437],
#         [0.9909]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0824],
#         [-0.0151],
#         [-0.3666]], grad_fn=<AsStridedBackward>) tensor([[0.9725],
#         [1.0124],
#         [0.9885]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0521],
#         [-0.0640],
#         [-0.3521]], grad_fn=<AsStridedBackward>) tensor([[0.9499],
#         [1.0206],
#         [0.9825]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0469],
#         [-0.0712],
#         [-0.3663]], grad_fn=<AsStridedBackward>) tensor([[0.9503],
#         [1.0103],
#         [0.9787]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0108],
#         [-0.1072],
#         [-0.4191]], grad_fn=<AsStridedBackward>) tensor([[0.9592],
#         [1.0095],
#         [0.9908]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0055],
#         [-0.0747],
#         [-0.4268]], grad_fn=<AsStridedBackward>) tensor([[0.9666],
#         [1.0378],
#         [0.9871]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0057],
#         [-0.0780],
#         [-0.4233]], grad_fn=<AsStridedBackward>) tensor([[0.9657],
#         [1.0295],
#         [0.9867]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0075],
#         [-0.0947],
#         [-0.4260]], grad_fn=<AsStridedBackward>) tensor([[0.9624],
#         [1.0242],
#         [0.9893]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0071],
#         [-0.0758],
#         [-0.4208]], grad_fn=<AsStridedBackward>) tensor([[0.9657],
#         [1.0274],
#         [0.9867]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0037],
#         [-0.0900],
#         [-0.4234]], grad_fn=<AsStridedBackward>) tensor([[0.9625],
#         [1.0237],
#         [0.9875]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0443],
#         [-0.0735],
#         [-0.3573]], grad_fn=<AsStridedBackward>) tensor([[0.9509],
#         [1.0286],
#         [0.9854]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0447],
#         [-0.0635],
#         [-0.3309]], grad_fn=<AsStridedBackward>) tensor([[0.9491],
#         [1.0295],
#         [0.9855]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0301],
#         [-0.0939],
#         [-0.3847]], grad_fn=<AsStridedBackward>) tensor([[0.9501],
#         [1.0511],
#         [0.9884]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0466],
#         [-0.0629],
#         [-0.3462]], grad_fn=<AsStridedBackward>) tensor([[0.9537],
#         [1.0390],
#         [0.9908]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0479],
#         [-0.0627],
#         [-0.3557]], grad_fn=<AsStridedBackward>) tensor([[0.9533],
#         [1.0279],
#         [0.9851]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0356],
#         [-0.0823],
#         [-0.3589]], grad_fn=<AsStridedBackward>) tensor([[0.9504],
#         [1.0370],
#         [0.9887]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0386],
#         [-0.0760],
#         [-0.3575]], grad_fn=<AsStridedBackward>) tensor([[0.9518],
#         [1.0324],
#         [0.9880]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0359],
#         [-0.0761],
#         [-0.3641]], grad_fn=<AsStridedBackward>) tensor([[0.9494],
#         [1.0294],
#         [0.9833]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0064],
#         [-0.0852],
#         [-0.4263]], grad_fn=<AsStridedBackward>) tensor([[0.9626],
#         [1.0197],
#         [0.9850]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0140],
#         [-0.0485],
#         [-0.4239]], grad_fn=<AsStridedBackward>) tensor([[0.9728],
#         [1.0369],
#         [0.9835]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0323],
#         [-0.0806],
#         [-0.3619]], grad_fn=<AsStridedBackward>) tensor([[0.9491],
#         [1.0265],
#         [0.9844]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0423],
#         [-0.0581],
#         [-0.3738]], grad_fn=<AsStridedBackward>) tensor([[0.9536],
#         [1.0159],
#         [0.9794]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0215],
#         [-0.0911],
#         [-0.3840]], grad_fn=<AsStridedBackward>) tensor([[0.9477],
#         [1.0131],
#         [0.9787]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0377],
#         [-0.0649],
#         [-0.3670]], grad_fn=<AsStridedBackward>) tensor([[0.9516],
#         [1.0167],
#         [0.9801]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0284],
#         [-0.0727],
#         [-0.3759]], grad_fn=<AsStridedBackward>) tensor([[0.9505],
#         [1.0186],
#         [0.9799]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0210],
#         [-0.0882],
#         [-0.3918]], grad_fn=<AsStridedBackward>) tensor([[0.9509],
#         [1.0067],
#         [0.9772]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0212],
#         [-0.0901],
#         [-0.3722]], grad_fn=<AsStridedBackward>) tensor([[0.9497],
#         [1.0398],
#         [0.9877]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0307],
#         [-0.0719],
#         [-0.3660]], grad_fn=<AsStridedBackward>) tensor([[0.9525],
#         [1.0344],
#         [0.9871]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0269],
#         [-0.0704],
#         [-0.3867]], grad_fn=<AsStridedBackward>) tensor([[0.9537],
#         [1.0126],
#         [0.9780]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0086],
#         [-0.1032],
#         [-0.3885]], grad_fn=<AsStridedBackward>) tensor([[0.9454],
#         [1.0164],
#         [0.9786]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0267],
#         [-0.0773],
#         [-0.3681]], grad_fn=<AsStridedBackward>) tensor([[0.9509],
#         [1.0273],
#         [0.9841]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0054],
#         [-0.1334],
#         [-0.3981]], grad_fn=<AsStridedBackward>) tensor([[0.9432],
#         [1.0412],
#         [0.9857]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0416],
#         [-0.1170],
#         [-0.4388]], grad_fn=<AsStridedBackward>) tensor([[0.9578],
#         [0.9976],
#         [0.9846]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0126],
#         [-0.0788],
#         [-0.4404]], grad_fn=<AsStridedBackward>) tensor([[0.9649],
#         [1.0261],
#         [0.9811]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0266],
#         [-0.0867],
#         [-0.4495]], grad_fn=<AsStridedBackward>) tensor([[0.9650],
#         [1.0274],
#         [0.9818]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0263],
#         [-0.0991],
#         [-0.4393]], grad_fn=<AsStridedBackward>) tensor([[0.9614],
#         [1.0064],
#         [0.9841]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0284],
#         [-0.0822],
#         [-0.4572]], grad_fn=<AsStridedBackward>) tensor([[0.9675],
#         [1.0331],
#         [0.9819]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0587],
#         [-0.1440],
#         [-0.4389]], grad_fn=<AsStridedBackward>) tensor([[0.9525],
#         [0.9751],
#         [0.9902]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0032],
#         [-0.0892],
#         [-0.4163]], grad_fn=<AsStridedBackward>) tensor([[0.9554],
#         [1.0142],
#         [0.9782]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0125],
#         [-0.0781],
#         [-0.4201]], grad_fn=<AsStridedBackward>) tensor([[0.9595],
#         [1.0048],
#         [0.9775]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0171],
#         [-0.0803],
#         [-0.3841]], grad_fn=<AsStridedBackward>) tensor([[0.9499],
#         [1.0150],
#         [0.9781]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0126],
#         [-0.1351],
#         [-0.4234]], grad_fn=<AsStridedBackward>) tensor([[0.9457],
#         [1.0081],
#         [0.9758]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0359],
#         [-0.0513],
#         [-0.3831]], grad_fn=<AsStridedBackward>) tensor([[0.9587],
#         [1.0196],
#         [0.9808]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0021],
#         [-0.1053],
#         [-0.3993]], grad_fn=<AsStridedBackward>) tensor([[0.9458],
#         [1.0101],
#         [0.9756]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0062],
#         [-0.0943],
#         [-0.3934]], grad_fn=<AsStridedBackward>) tensor([[0.9473],
#         [1.0164],
#         [0.9784]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0181],
#         [-0.0821],
#         [-0.3781]], grad_fn=<AsStridedBackward>) tensor([[0.9509],
#         [1.0181],
#         [0.9806]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0284],
#         [-0.0874],
#         [-0.4500]], grad_fn=<AsStridedBackward>) tensor([[0.9632],
#         [1.0165],
#         [0.9795]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0557],
#         [-0.1268],
#         [-0.4530]], grad_fn=<AsStridedBackward>) tensor([[0.9544],
#         [0.9921],
#         [0.9809]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0014],
#         [-0.0991],
#         [-0.3894]], grad_fn=<AsStridedBackward>) tensor([[0.9485],
#         [1.0251],
#         [0.9829]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0071],
#         [-0.0917],
#         [-0.3903]], grad_fn=<AsStridedBackward>) tensor([[0.9490],
#         [1.0194],
#         [0.9804]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0019],
#         [-0.0962],
#         [-0.3919]], grad_fn=<AsStridedBackward>) tensor([[0.9500],
#         [1.0355],
#         [0.9859]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0421],
#         [-0.0438],
#         [-0.4235]], grad_fn=<AsStridedBackward>) tensor([[0.9697],
#         [0.9992],
#         [0.9792]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0585],
#         [-0.1085],
#         [-0.4689]], grad_fn=<AsStridedBackward>) tensor([[0.9615],
#         [1.0079],
#         [0.9825]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0432],
#         [-0.0831],
#         [-0.4720]], grad_fn=<AsStridedBackward>) tensor([[0.9675],
#         [1.0277],
#         [0.9799]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0202],
#         [-0.1271],
#         [-0.4294]], grad_fn=<AsStridedBackward>) tensor([[0.9447],
#         [1.0234],
#         [0.9770]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0075],
#         [-0.0861],
#         [-0.3813]], grad_fn=<AsStridedBackward>) tensor([[0.9502],
#         [1.0231],
#         [0.9834]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0089],
#         [-0.1098],
#         [-0.4183]], grad_fn=<AsStridedBackward>) tensor([[0.9484],
#         [1.0275],
#         [0.9797]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0100],
#         [-0.0768],
#         [-0.3580]], grad_fn=<AsStridedBackward>) tensor([[0.9508],
#         [1.0304],
#         [0.9894]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0275],
#         [-0.1035],
#         [-0.4404]], grad_fn=<AsStridedBackward>) tensor([[0.9537],
#         [1.0016],
#         [0.9746]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0114],
#         [-0.0822],
#         [-0.4302]], grad_fn=<AsStridedBackward>) tensor([[0.9571],
#         [1.0169],
#         [0.9763]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0059],
#         [-0.0818],
#         [-0.3973]], grad_fn=<AsStridedBackward>) tensor([[0.9524],
#         [1.0166],
#         [0.9794]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0142],
#         [-0.1128],
#         [-0.4009]], grad_fn=<AsStridedBackward>) tensor([[0.9448],
#         [1.0270],
#         [0.9817]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0067],
#         [-0.0963],
#         [-0.4044]], grad_fn=<AsStridedBackward>) tensor([[0.9465],
#         [1.0127],
#         [0.9763]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0046],
#         [-0.0936],
#         [-0.4091]], grad_fn=<AsStridedBackward>) tensor([[0.9489],
#         [1.0075],
#         [0.9748]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0605],
#         [-0.0962],
#         [-0.4812]], grad_fn=<AsStridedBackward>) tensor([[0.9638],
#         [1.0152],
#         [0.9780]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1167],
#         [-0.1712],
#         [-0.4739]], grad_fn=<AsStridedBackward>) tensor([[0.9484],
#         [0.9592],
#         [0.9878]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0049],
#         [-0.0885],
#         [-0.4109]], grad_fn=<AsStridedBackward>) tensor([[0.9500],
#         [1.0093],
#         [0.9750]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0224],
#         [-0.1120],
#         [-0.4187]], grad_fn=<AsStridedBackward>) tensor([[0.9433],
#         [1.0069],
#         [0.9726]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0627],
#         [-0.0939],
#         [-0.4882]], grad_fn=<AsStridedBackward>) tensor([[0.9650],
#         [1.0161],
#         [0.9776]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0819],
#         [-0.1094],
#         [-0.4946]], grad_fn=<AsStridedBackward>) tensor([[0.9628],
#         [1.0121],
#         [0.9795]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0396],
#         [-0.0937],
#         [-0.4573]], grad_fn=<AsStridedBackward>) tensor([[0.9575],
#         [1.0081],
#         [0.9737]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0521],
#         [-0.1428],
#         [-0.4670]], grad_fn=<AsStridedBackward>) tensor([[0.9506],
#         [0.9781],
#         [0.9734]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0562],
#         [-0.0821],
#         [-0.4822]], grad_fn=<AsStridedBackward>) tensor([[0.9662],
#         [1.0217],
#         [0.9754]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0673],
#         [-0.1058],
#         [-0.4820]], grad_fn=<AsStridedBackward>) tensor([[0.9603],
#         [1.0040],
#         [0.9762]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0114],
#         [-0.0932],
#         [-0.3950]], grad_fn=<AsStridedBackward>) tensor([[0.9486],
#         [1.0231],
#         [0.9822]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0251],
#         [-0.1101],
#         [-0.4326]], grad_fn=<AsStridedBackward>) tensor([[0.9464],
#         [1.0172],
#         [0.9748]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0255],
#         [-0.0698],
#         [-0.4666]], grad_fn=<AsStridedBackward>) tensor([[0.9647],
#         [1.0096],
#         [0.9739]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0762],
#         [-0.1074],
#         [-0.4854]], grad_fn=<AsStridedBackward>) tensor([[0.9594],
#         [1.0066],
#         [0.9752]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0120],
#         [-0.0839],
#         [-0.3963]], grad_fn=<AsStridedBackward>) tensor([[0.9516],
#         [1.0275],
#         [0.9856]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0288],
#         [-0.1130],
#         [-0.4306]], grad_fn=<AsStridedBackward>) tensor([[0.9460],
#         [1.0306],
#         [0.9795]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1301],
#         [-0.1367],
#         [-0.5164]], grad_fn=<AsStridedBackward>) tensor([[0.9575],
#         [1.0031],
#         [0.9799]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0662],
#         [-0.0872],
#         [-0.4940]], grad_fn=<AsStridedBackward>) tensor([[0.9648],
#         [1.0132],
#         [0.9760]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0334],
#         [-0.1115],
#         [-0.4254]], grad_fn=<AsStridedBackward>) tensor([[0.9433],
#         [1.0144],
#         [0.9759]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0210],
#         [-0.0898],
#         [-0.4177]], grad_fn=<AsStridedBackward>) tensor([[0.9481],
#         [1.0115],
#         [0.9756]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0838],
#         [-0.0802],
#         [-0.5197]], grad_fn=<AsStridedBackward>) tensor([[0.9690],
#         [1.0298],
#         [0.9735]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1060],
#         [-0.1118],
#         [-0.5139]], grad_fn=<AsStridedBackward>) tensor([[0.9619],
#         [1.0047],
#         [0.9797]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0310],
#         [-0.0961],
#         [-0.4215]], grad_fn=<AsStridedBackward>) tensor([[0.9476],
#         [1.0234],
#         [0.9795]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0430],
#         [-0.1232],
#         [-0.4270]], grad_fn=<AsStridedBackward>) tensor([[0.9418],
#         [1.0283],
#         [0.9796]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1056],
#         [-0.1034],
#         [-0.5174]], grad_fn=<AsStridedBackward>) tensor([[0.9626],
#         [1.0111],
#         [0.9770]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0525],
#         [-0.0575],
#         [-0.5006]], grad_fn=<AsStridedBackward>) tensor([[0.9707],
#         [1.0263],
#         [0.9718]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0527],
#         [-0.1014],
#         [-0.4567]], grad_fn=<AsStridedBackward>) tensor([[0.9488],
#         [1.0028],
#         [0.9707]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[ 0.0054],
#         [-0.0198],
#         [-0.4128]], grad_fn=<AsStridedBackward>) tensor([[0.9622],
#         [1.0422],
#         [0.9795]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0404],
#         [-0.1001],
#         [-0.4355]], grad_fn=<AsStridedBackward>) tensor([[0.9450],
#         [1.0086],
#         [0.9730]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0312],
#         [-0.0855],
#         [-0.4011]], grad_fn=<AsStridedBackward>) tensor([[0.9414],
#         [1.0142],
#         [0.9750]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0262],
#         [-0.0811],
#         [-0.4117]], grad_fn=<AsStridedBackward>) tensor([[0.9484],
#         [1.0149],
#         [0.9779]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0574],
#         [-0.1202],
#         [-0.4481]], grad_fn=<AsStridedBackward>) tensor([[0.9399],
#         [1.0122],
#         [0.9715]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0547],
#         [-0.1022],
#         [-0.4524]], grad_fn=<AsStridedBackward>) tensor([[0.9464],
#         [1.0056],
#         [0.9707]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0485],
#         [-0.0851],
#         [-0.4540]], grad_fn=<AsStridedBackward>) tensor([[0.9500],
#         [1.0016],
#         [0.9697]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0739],
#         [-0.1461],
#         [-0.4710]], grad_fn=<AsStridedBackward>) tensor([[0.9370],
#         [1.0342],
#         [0.9733]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0381],
#         [-0.0882],
#         [-0.4179]], grad_fn=<AsStridedBackward>) tensor([[0.9475],
#         [1.0253],
#         [0.9813]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0496],
#         [-0.1067],
#         [-0.4358]], grad_fn=<AsStridedBackward>) tensor([[0.9443],
#         [1.0194],
#         [0.9761]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0259],
#         [-0.0702],
#         [-0.3620]], grad_fn=<AsStridedBackward>) tensor([[0.9399],
#         [1.0256],
#         [0.9829]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0785],
#         [-0.1112],
#         [-0.4811]], grad_fn=<AsStridedBackward>) tensor([[0.9494],
#         [0.9987],
#         [0.9685]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0494],
#         [-0.0697],
#         [-0.4614]], grad_fn=<AsStridedBackward>) tensor([[0.9566],
#         [1.0162],
#         [0.9710]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1017],
#         [-0.0974],
#         [-0.5142]], grad_fn=<AsStridedBackward>) tensor([[0.9601],
#         [1.0087],
#         [0.9702]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1161],
#         [-0.1187],
#         [-0.5146]], grad_fn=<AsStridedBackward>) tensor([[0.9553],
#         [0.9928],
#         [0.9714]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1225],
#         [-0.1087],
#         [-0.5314]], grad_fn=<AsStridedBackward>) tensor([[0.9608],
#         [1.0067],
#         [0.9722]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1377],
#         [-0.1108],
#         [-0.5449]], grad_fn=<AsStridedBackward>) tensor([[0.9621],
#         [1.0152],
#         [0.9710]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0902],
#         [-0.0826],
#         [-0.5273]], grad_fn=<AsStridedBackward>) tensor([[0.9657],
#         [1.0165],
#         [0.9680]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1449],
#         [-0.1210],
#         [-0.5452]], grad_fn=<AsStridedBackward>) tensor([[0.9601],
#         [1.0066],
#         [0.9723]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0864],
#         [-0.1047],
#         [-0.4964]], grad_fn=<AsStridedBackward>) tensor([[0.9540],
#         [1.0004],
#         [0.9660]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1420],
#         [-0.1699],
#         [-0.5180]], grad_fn=<AsStridedBackward>) tensor([[0.9417],
#         [1.0005],
#         [0.9652]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1080],
#         [-0.1155],
#         [-0.5144]], grad_fn=<AsStridedBackward>) tensor([[0.9544],
#         [0.9990],
#         [0.9657]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0853],
#         [-0.0893],
#         [-0.5040]], grad_fn=<AsStridedBackward>) tensor([[0.9599],
#         [1.0045],
#         [0.9662]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0676],
#         [-0.0806],
#         [-0.5069]], grad_fn=<AsStridedBackward>) tensor([[0.9619],
#         [0.9997],
#         [0.9659]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1405],
#         [-0.1166],
#         [-0.5422]], grad_fn=<AsStridedBackward>) tensor([[0.9598],
#         [1.0062],
#         [0.9678]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0596],
#         [-0.1210],
#         [-0.4279]], grad_fn=<AsStridedBackward>) tensor([[0.9412],
#         [1.0213],
#         [0.9756]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0635],
#         [-0.1147],
#         [-0.4555]], grad_fn=<AsStridedBackward>) tensor([[0.9445],
#         [1.0137],
#         [0.9697]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1147],
#         [-0.1103],
#         [-0.5242]], grad_fn=<AsStridedBackward>) tensor([[0.9574],
#         [0.9980],
#         [0.9651]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1201],
#         [-0.1016],
#         [-0.5298]], grad_fn=<AsStridedBackward>) tensor([[0.9604],
#         [1.0094],
#         [0.9646]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0763],
#         [-0.1306],
#         [-0.4743]], grad_fn=<AsStridedBackward>) tensor([[0.9391],
#         [1.0138],
#         [0.9639]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0592],
#         [-0.1109],
#         [-0.4378]], grad_fn=<AsStridedBackward>) tensor([[0.9462],
#         [1.0187],
#         [0.9749]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1547],
#         [-0.1128],
#         [-0.5627]], grad_fn=<AsStridedBackward>) tensor([[0.9633],
#         [1.0134],
#         [0.9664]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1190],
#         [-0.1262],
#         [-0.5200]], grad_fn=<AsStridedBackward>) tensor([[0.9542],
#         [0.9740],
#         [0.9722]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0728],
#         [-0.1256],
#         [-0.4620]], grad_fn=<AsStridedBackward>) tensor([[0.9432],
#         [1.0184],
#         [0.9704]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0644],
#         [-0.1140],
#         [-0.4478]], grad_fn=<AsStridedBackward>) tensor([[0.9444],
#         [1.0179],
#         [0.9715]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0797],
#         [-0.1166],
#         [-0.4722]], grad_fn=<AsStridedBackward>) tensor([[0.9438],
#         [1.0015],
#         [0.9623]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.0679],
#         [-0.1042],
#         [-0.4902]], grad_fn=<AsStridedBackward>) tensor([[0.9529],
#         [0.9964],
#         [0.9630]], grad_fn=<AsStridedBackward>)
# Normal(loc: torch.Size([3]), scale: torch.Size([3]))
# tensor([[-0.1450],
#         [-0.1116],
#         [-0.5543]], grad_fn=<AsStridedBackward>) tensor([[0.9609],
#         [1.0072],
#         [0.9635]], grad_fn=<AsStridedBackward>)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-66d784b66c1a> in <module>()
# ----> 1 train(data, cnp, 15, test_data)
#
# <ipython-input-16-0110f8bcbc46> in train(data, cnp, epochs, test_data)
#      39             test_y = function[1][perm][num_context:num_points].unsqueeze(0)
#      40
# ---> 41             mu, sigma, log_p, en_dist, t_en_dist = cnp(context_x, context_y, test_x, test_y)
#      42             loss = lossf(log_p, torch.distributions.Normal(torch.zeros(cnp.encoded_size), 1), en_dist, t_en_dist, alpha)
#      43             loss.backward()
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-15-f4e150425e75> in forward(self, context_x, context_y, target_x, target_y)
#       7
#       8     def forward(self, context_x, context_y, target_x, target_y=None):
# ----> 9         en_mu, en_sigma, en_dist = self._encoder(context_x, context_y)
#      10         if target_y is not None:
#      11             t_en_mu, t_en_sigma, t_en_dist = self._encoder(target_x, target_y)
#
# ~\Anaconda3\lib\site-packages\torch\nn\modules\module.py in __call__(self, *input, **kwargs)
#     491             result = self._slow_forward(*input, **kwargs)
#     492         else:
# --> 493             result = self.forward(*input, **kwargs)
#     494         for hook in self._forward_hooks.values():
#     495             hook_result = hook(self, input, result)
#
# <ipython-input-12-44517043c290> in forward(self, x, y)
#      23         out_sigma = torch.mean(sigma, dim=0)
#      24
# ---> 25         print(out_mu.reshape(self.output_sizes, 1), out_sigma.reshape(self.output_sizes, 1))
#      26         print(torch.distributions.Normal(out_mu, out_sigma))
#      27
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write(self, text)
#      38
#      39     def write(self, text):
# ---> 40         self.__convertor.write(text)
#      41
#      42
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write(self, text)
#     139     def write(self, text):
#     140         if self.strip or self.convert:
# --> 141             self.write_and_convert(text)
#     142         else:
#     143             self.wrapped.write(text)
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write_and_convert(self, text)
#     167             self.convert_ansi(*match.groups())
#     168             cursor = end
# --> 169         self.write_plain_text(text, cursor, len(text))
#     170
#     171
#
# ~\Anaconda3\lib\site-packages\colorama\ansitowin32.py in write_plain_text(self, text, start, end)
#     173         if start < end:
#     174             self.wrapped.write(text[start:end])
# --> 175             self.wrapped.flush()
#     176
#     177
#
# ~\Anaconda3\lib\site-packages\ipykernel\iostream.py in flush(self)
#     340                 self.pub_thread.schedule(evt.set)
#     341                 # and give a timeout to avoid
# --> 342                 if not evt.wait(self.flush_timeout):
#     343                     # write directly to __stderr__ instead of warning because
#     344                     # if this is happening sys.stderr may be the problem.
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     549             signaled = self._flag
#     550             if not signaled:
# --> 551                 signaled = self._cond.wait(timeout)
#     552             return signaled
#     553
#
# ~\Anaconda3\lib\threading.py in wait(self, timeout)
#     297             else:
#     298                 if timeout > 0:
# --> 299                     gotit = waiter.acquire(True, timeout)
#     300                 else:
#     301                     gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
plot_priors(cnp, 10)
