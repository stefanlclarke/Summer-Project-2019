# %%
import numpy as np
import torch
import torch.nn as nn
from training import train
from NP import NP
import matplotlib.pyplot as plt

# %%
def f(point, alpha):
    return 100*np.sin(point*alpha)

num_datapoints = 1000
alpha_range = [-2, 2]
x_dimension = 1
y_dimension = 1

mesh = torch.linspace(-2, 2, 100).unsqueeze(0).transpose(0,1)
datapoints = []
for _ in range(num_datapoints):
    num = np.random.uniform(alpha_range[0], alpha_range[1])
    value = f(mesh, num)
    datapoints.append([mesh, value])

points = np.random.choice(100, 10)
testpoints = [mesh[points], f(mesh[points], 1)]

# %%
model = NP(3, 1, 1)
optimizer = torch.optim.Adam(model.parameters(), lr=3e-3)

# %%
def sample_plot(np, context, linspace):
    context_x = context[0]
    context_y = context[1]
    
    mu, sigma, log_p, en_dist, t_en_dist, MSE  = np(context_x, context_y, linspace)
    low = mu-sigma
    high = mu+sigma
    plt.plot(linspace.transpose(0,1).squeeze().numpy(), mu.transpose(0,1).squeeze().detach().numpy())
    plt.fill_between(linspace.transpose(0,1).squeeze().numpy(), low.transpose(0,1).squeeze().detach().numpy(), high.transpose(0,1).squeeze().detach().numpy(), facecolor='#65c9f7', interpolate=True)
    plt.scatter(context[0], context[1], c='black')
    plt.show()

# %%
for i in range(30):
    print(5*i)
    train(datapoints, model, 5, 99, 1, optimizer)
    sample_plot(model, testpoints, mesh)
# Out:
# 0
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 83.49050903320312.
# EPOCH LOSS 83.49050903320312
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 8.063128471374512.
# EPOCH LOSS 8.063128471374512
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.463233947753906.
# EPOCH LOSS 5.463233947753906
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.449259281158447.
# EPOCH LOSS 5.449259281158447
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.550525665283203.
# EPOCH LOSS 5.550525665283203
# 5
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.446660995483398.
# EPOCH LOSS 5.446660995483398
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.434024810791016.
# EPOCH LOSS 5.434024810791016
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.696343421936035.
# EPOCH LOSS 5.696343421936035
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.488570690155029.
# EPOCH LOSS 5.488570690155029
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.457110404968262.
# EPOCH LOSS 5.457110404968262
# 10
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.448063850402832.
# EPOCH LOSS 5.448063850402832
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.416779518127441.
# EPOCH LOSS 5.416779518127441
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.401737689971924.
# EPOCH LOSS 5.401737689971924
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.382878303527832.
# EPOCH LOSS 5.382878303527832
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.36463737487793.
# EPOCH LOSS 5.36463737487793
# 15
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.346346378326416.
# EPOCH LOSS 5.346346378326416
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.316650390625...
# EPOCH LOSS 5.316650390625
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.597024440765381.
# EPOCH LOSS 5.597024440765381
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.372075080871582.
# EPOCH LOSS 5.372075080871582
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.335729122161865.
# EPOCH LOSS 5.335729122161865
# 20
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.309587001800537.
# EPOCH LOSS 5.309587001800537
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.30008602142334.
# EPOCH LOSS 5.30008602142334
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.297378063201904.
# EPOCH LOSS 5.297378063201904
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.3160786628723145.
# EPOCH LOSS 5.3160786628723145
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.284683704376221.
# EPOCH LOSS 5.284683704376221
# 25
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 6.33402681350708.
# EPOCH LOSS 6.33402681350708
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 6.953021049499512.
# EPOCH LOSS 6.953021049499512
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.281060695648193.
# EPOCH LOSS 5.281060695648193
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.238613605499268.
# EPOCH LOSS 5.238613605499268
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.208585262298584.
# EPOCH LOSS 5.208585262298584
# 30
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.197766304016113.
# EPOCH LOSS 5.197766304016113
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.224351406097412.
# EPOCH LOSS 5.224351406097412
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.205996513366699.
# EPOCH LOSS 5.205996513366699
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.193783760070801.
# EPOCH LOSS 5.193783760070801
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.2046799659729..
# EPOCH LOSS 5.2046799659729
# 35
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.194693565368652.
# EPOCH LOSS 5.194693565368652
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.227956295013428.
# EPOCH LOSS 5.227956295013428
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.2199320793151855.
# EPOCH LOSS 5.2199320793151855
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.285949230194092.
# EPOCH LOSS 5.285949230194092
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.199444770812988.
# EPOCH LOSS 5.199444770812988
# 40
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.199310779571533.
# EPOCH LOSS 5.199310779571533
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.2006516456604..
# EPOCH LOSS 5.2006516456604
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.233891487121582.
# EPOCH LOSS 5.233891487121582
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.189702033996582.
# EPOCH LOSS 5.189702033996582
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.1748576164245605.
# EPOCH LOSS 5.1748576164245605
# 45
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.191711902618408.
# EPOCH LOSS 5.191711902618408
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.170778751373291.
# EPOCH LOSS 5.170778751373291
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.201166152954102.
# EPOCH LOSS 5.201166152954102
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.2008185386657715.
# EPOCH LOSS 5.2008185386657715
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.192843914031982.
# EPOCH LOSS 5.192843914031982
# 50
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.198927879333496.
# EPOCH LOSS 5.198927879333496
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.232360363006592.
# EPOCH LOSS 5.232360363006592
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.2368903160095215.
# EPOCH LOSS 5.2368903160095215
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.198263645172119.
# EPOCH LOSS 5.198263645172119
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.189783096313477.
# EPOCH LOSS 5.189783096313477
# 55
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.169925689697266.
# EPOCH LOSS 5.169925689697266
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.165308475494385.
# EPOCH LOSS 5.165308475494385
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.427863597869873.
# EPOCH LOSS 5.427863597869873
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.209149360656738.
# EPOCH LOSS 5.209149360656738
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.1743059158325195.
# EPOCH LOSS 5.1743059158325195
# 60
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.1698102951049805.
# EPOCH LOSS 5.1698102951049805
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.231359004974365.
# EPOCH LOSS 5.231359004974365
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.203935146331787.
# EPOCH LOSS 5.203935146331787
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.340184688568115.
# EPOCH LOSS 5.340184688568115
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.209558486938477.
# EPOCH LOSS 5.209558486938477
# 65
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.193350791931152.
# EPOCH LOSS 5.193350791931152
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.187760829925537.
# EPOCH LOSS 5.187760829925537
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.175457000732422.
# EPOCH LOSS 5.175457000732422
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.169462203979492.
# EPOCH LOSS 5.169462203979492
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.162956237792969.
# EPOCH LOSS 5.162956237792969
# 70
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.199365139007568.
# EPOCH LOSS 5.199365139007568
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.287170886993408.
# EPOCH LOSS 5.287170886993408
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.186944484710693.
# EPOCH LOSS 5.186944484710693
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.184391498565674.
# EPOCH LOSS 5.184391498565674
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.156767845153809.
# EPOCH LOSS 5.156767845153809
# 75
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.170010566711426.
# EPOCH LOSS 5.170010566711426
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.1537933349609375.
# EPOCH LOSS 5.1537933349609375
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.022366046905518.
# EPOCH LOSS 5.022366046905518
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.775845050811768.
# EPOCH LOSS 4.775845050811768
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.507361888885498.
# EPOCH LOSS 4.507361888885498
# 80
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.50172233581543..
# EPOCH LOSS 4.50172233581543
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.896487236022949.
# EPOCH LOSS 4.896487236022949
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.452757358551025.
# EPOCH LOSS 4.452757358551025
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.58469820022583..
# EPOCH LOSS 4.58469820022583
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.302576541900635.
# EPOCH LOSS 4.302576541900635
# 85
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.238674640655518.
# EPOCH LOSS 4.238674640655518
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.222458362579346.
# EPOCH LOSS 4.222458362579346
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.303021430969238.
# EPOCH LOSS 4.303021430969238
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.423801898956299.
# EPOCH LOSS 4.423801898956299
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.461723327636719.
# EPOCH LOSS 5.461723327636719
# 90
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 5.3624138832092285.
# EPOCH LOSS 5.3624138832092285
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.944333076477051.
# EPOCH LOSS 4.944333076477051
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.645628452301025.
# EPOCH LOSS 4.645628452301025
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.4636054039001465.
# EPOCH LOSS 4.4636054039001465
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.638307094573975.
# EPOCH LOSS 4.638307094573975
# 95
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.438913822174072.
# EPOCH LOSS 4.438913822174072
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.3577961921691895.
# EPOCH LOSS 4.3577961921691895
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.338319301605225.
# EPOCH LOSS 4.338319301605225
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.34541130065918..
# EPOCH LOSS 4.34541130065918
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.313967704772949.
# EPOCH LOSS 4.313967704772949
# 100
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 4.285268783569336.
# EPOCH LOSS 4.285268783569336
# Epoch 2 Progress: |█████████████████████-----------------------------| 43.9% Complete.  Iteration = 439. Average loss = 1.887520432472229...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-60-73afc932da15> in <module>
#       1 for i in range(30):
#       2     print(5*i)
# ----> 3     train(datapoints, model, 5, 99, 1, optimizer)
#       4     sample_plot(model, testpoints, mesh)
#
# ~/Desktop/Repo/Summer-Project-2019/Modular Convolutional NP/training.py in train(data, cnp, epochs, num_test_maximum, alpha, optimizer, f, f_every)
#      46
#      47             loss.backward()
# ---> 48             optimizer.step()
#      49
#      50             total_loss += loss/len(data)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#      99                     denom = max_exp_avg_sq.sqrt().add_(group['eps'])
#     100                 else:
# --> 101                     denom = exp_avg_sq.sqrt().add_(group['eps'])
#     102
#     103                 bias_correction1 = 1 - beta1 ** state['step']
#
# KeyboardInterrupt:

# %%
points = np.random.choice(100, 5)
testpoints = [mesh[points], f(mesh[points], 2)]
sample_plot(model, testpoints, mesh)
