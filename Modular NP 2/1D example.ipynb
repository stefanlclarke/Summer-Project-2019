# %%
import numpy as np
import torch
import torch.nn as nn
from training import train
from NP import NP
import matplotlib.pyplot as plt

# %%
def f(point, alpha):
    return np.sin(point*alpha)

num_datapoints = 1000
alpha_range = [-2, 2]
x_dimension = 1
y_dimension = 1

mesh = torch.linspace(-2, 2, 100).unsqueeze(0).transpose(0,1)
datapoints = []
for _ in range(num_datapoints):
    num = np.random.uniform(alpha_range[0], alpha_range[1])
    value = f(mesh, num)
    datapoints.append([mesh, value])

points = np.random.choice(100, 10)
testpoints = [mesh[points], f(mesh[points], 1)]

# %%
model = NP(3, 1, 1)
optimizer = torch.optim.Adam(model.parameters(), lr=3e-3)

# %%
def sample_plot(np, context, linspace):
    context_x = context[0]
    context_y = context[1]
    
    mu, sigma, log_p, en_dist, t_en_dist, MSE  = np(context_x, context_y, linspace)
    low = mu-sigma
    high = mu+sigma
    plt.plot(linspace.transpose(0,1).squeeze().numpy(), mu.transpose(0,1).squeeze().detach().numpy())
    plt.fill_between(linspace.transpose(0,1).squeeze().numpy(), low.transpose(0,1).squeeze().detach().numpy(), high.transpose(0,1).squeeze().detach().numpy(), facecolor='#65c9f7', interpolate=True)
    plt.scatter(context[0], context[1], c='black')
    plt.show()

# %%
for i in range(30):
    print(5*i)
    train(datapoints, model, 5, 99, 1, optimizer)
    sample_plot(model, testpoints, mesh)
# Out:
# 0
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = 0.4890115261077881.
# EPOCH LOSS 0.4890115261077881
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.006218015681952238.
# EPOCH LOSS -0.006218015681952238
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.14198635518550873.
# EPOCH LOSS -0.14198635518550873
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.17990995943546295.
# EPOCH LOSS -0.17990995943546295
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.13022778928279877.
# EPOCH LOSS -0.13022778928279877
# 5
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.1608331799507141.
# EPOCH LOSS -0.1608331799507141
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.22073090076446533.
# EPOCH LOSS -0.22073090076446533
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.21259285509586334.
# EPOCH LOSS -0.21259285509586334
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.24064740538597107.
# EPOCH LOSS -0.24064740538597107
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.12812888622283936.
# EPOCH LOSS -0.12812888622283936
# 10
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.2963811159133911.
# EPOCH LOSS -0.2963811159133911
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.22185996174812317.
# EPOCH LOSS -0.22185996174812317
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.35206931829452515.
# EPOCH LOSS -0.35206931829452515
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.27416688203811646.
# EPOCH LOSS -0.27416688203811646
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.3878737688064575.
# EPOCH LOSS -0.3878737688064575
# 15
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.37824273109436035.
# EPOCH LOSS -0.37824273109436035
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.3691070079803467.
# EPOCH LOSS -0.3691070079803467
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.41191384196281433.
# EPOCH LOSS -0.41191384196281433
# Epoch 4 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.34611400961875916.
# EPOCH LOSS -0.34611400961875916
# Epoch 5 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.38417574763298035.
# EPOCH LOSS -0.38417574763298035
# 20
# Epoch 1 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.44149813055992126.
# EPOCH LOSS -0.44149813055992126
# Epoch 2 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.262309193611145....
# EPOCH LOSS -0.262309193611145
# Epoch 3 Progress: |██████████████████████████████████████████████████| 100.0% Complete.  Iteration = 1000. Average loss = -0.40528637170791626.
# EPOCH LOSS -0.40528637170791626
# Epoch 4 Progress: |██████████----------------------------------------| 21.8% Complete.  Iteration = 218. Average loss = -0.07957662642002106..
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-73afc932da15> in <module>
#       1 for i in range(30):
#       2     print(5*i)
# ----> 3     train(datapoints, model, 5, 99, 1, optimizer)
#       4     sample_plot(model, testpoints, mesh)
#
# ~/Desktop/Repo/Summer-Project-2019/Modular NP 2/training.py in train(data, cnp, epochs, num_test_maximum, alpha, optimizer, f, f_every)
#      46
#      47             loss.backward()
# ---> 48             optimizer.step()
#      49
#      50             total_loss += loss/len(data)
#
# ~/anaconda3/lib/python3.7/site-packages/torch/optim/adam.py in step(self, closure)
#      91
#      92                 # Decay the first and second moment running average coefficient
# ---> 93                 exp_avg.mul_(beta1).add_(1 - beta1, grad)
#      94                 exp_avg_sq.mul_(beta2).addcmul_(1 - beta2, grad, grad)
#      95                 if amsgrad:
#
# KeyboardInterrupt:

# %%
points = np.random.choice(100, 5)
testpoints = [mesh[points], f(mesh[points], 2)]
sample_plot(model, testpoints, mesh)
