# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Variable

#gnerates 3D data. The network will predict z from x and y.
datapoints = 3000
testpoints = 1000

#the function which will generate the z coordinate from x and y in the data (no outliers for now)
def f(x, y):
    return 2*y + np.cos(5*x)

x_train = []
z_train = []
for i in range(datapoints):
    x_train.append(np.random.uniform(0, 1, size = 2))
    
for i in range(len(x_train)):
    z_train.append(f(x_train[i][0], x_train[i][1]))

x_test = []
z_test = []
for i in range(testpoints):
    x_test.append(np.random.uniform(0, 1, size = 2))
    
for i in range(len(x_test)):
    z_test.append(f(x_test[i][0], x_test[i][1]))    

x_train = np.array(x_train)
z_train = np.array(z_train)
x_test = np.array(x_test)
z_test = np.array(z_test)

# %%
#a plot of the data

xs = x_train[:,0]
ys = x_train[:,1]
zs = z_train

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs, ys, zs, c='r', marker = '.')

# %%
class Feedforward(nn.Module):
    
    def __init__(self, input_size, hidden_size_1, hidden_size_2, hidden_size_3):
        super(Feedforward, self).__init__()
        self.input_size = input_size
        self.hidden_size_1 = hidden_size_1
        self.hidden_size_2 = hidden_size_2
        self.hidden_size_3 = hidden_size_3
        self.fc1 = torch.nn.Linear(self.input_size, self.hidden_size_1)
        self.relu1 = torch.nn.ReLU()
        self.fc2 = torch.nn.Linear(self.hidden_size_1, self.hidden_size_2)
        self.relu2 = torch.nn.ReLU()
        self.fc3 = torch.nn.Linear(self.hidden_size_2, self.hidden_size_3)
        self.relu3 = torch.nn.ReLU()
        self.fc4 = torch.nn.Linear(self.hidden_size_3, 1)
        #self.sigmoid = torch.nn.Sigmoid()
        
    def forward(self, x):
        hidden_1 = self.fc1(x)
        relu_1 = self.relu1(hidden_1)
        hidden_2 = self.fc2(relu_1)
        relu_2 = self.relu2(hidden_2)
        hidden_3 = self.fc3(relu_2)
        relu_3 = self.relu3(hidden_3)
        output_1 = self.fc4(relu_3)
        #output = self.sigmoid(output_1)
        return output_1

# %%
network = Feedforward(2, 10, 10, 10)
criterion = torch.nn.MSELoss()
optimizer = torch.optim.SGD(network.parameters(), lr=0.1)

x_train = torch.from_numpy(x_train)
z_train = torch.from_numpy(z_train)
x_test = torch.from_numpy(x_test)
z_test = torch.from_numpy(z_test)

# %%
network.eval()
z_pred = network.forward(x_test.float())
before_train = criterion(z_pred.squeeze(), z_test.float())
print('Test loss before training', before_train.item())
# Out:
# Test loss before training 1.7452449798583984

# %%
z_test_pred = network.forward(x_test.float())

initial_x_test = x_test.detach().numpy()
initial_z_test_pred = z_test_pred.detach().numpy()

xs = initial_x_test[:,0]
ys = initial_x_test[:,1]
zs = initial_z_test_pred

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs, ys, zs, c='r', marker = '.')

print(network)
# Out:
# Feedforward(
#   (fc1): Linear(in_features=2, out_features=10, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=10, out_features=10, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=10, out_features=10, bias=True)
#   (relu3): ReLU()
#   (fc4): Linear(in_features=10, out_features=1, bias=True)
# )

# %%
#network.train()
epoch = 5
for epoch in range(epoch):
    for i in range(len(x_train)):
        X, Y = x_train[i], z_train[i]
        X, Y = Variable(torch.FloatTensor(X.float()).float(), requires_grad=True), Variable(torch.FloatTensor([Y.float()]).float(), requires_grad=False)
        optimizer.zero_grad()
        outputs = network(X)
        loss = criterion(outputs, Y)
        loss.backward()
        optimizer.step()
        if i % 300 == 0:
            print("Epoch {} - loss: {}".format(epoch, loss.data))
# Out:
# Epoch 0 - loss: 0.32552412152290344
# Epoch 0 - loss: 0.8810787200927734
# Epoch 0 - loss: 0.1730370819568634
# Epoch 0 - loss: 2.052124261856079
# Epoch 0 - loss: 0.0188192930072546
# Epoch 0 - loss: 0.23995675146579742
# Epoch 0 - loss: 0.016117095947265625
# Epoch 0 - loss: 0.1324884593486786
# Epoch 0 - loss: 0.24983635544776917
# Epoch 0 - loss: 0.012485423125326633
# Epoch 1 - loss: 0.022960374131798744
# Epoch 1 - loss: 0.013342458754777908
# Epoch 1 - loss: 0.007446710020303726
# Epoch 1 - loss: 0.17499376833438873
# Epoch 1 - loss: 0.00011521282431203872
# Epoch 1 - loss: 0.015863599255681038
# Epoch 1 - loss: 0.0005318883922882378
# Epoch 1 - loss: 0.009811880066990852
# Epoch 1 - loss: 0.017206266522407532
# Epoch 1 - loss: 0.10191716998815536
# Epoch 2 - loss: 0.01055789366364479
# Epoch 2 - loss: 0.038728147745132446
# Epoch 2 - loss: 0.00016815443814266473
# Epoch 2 - loss: 0.022560330107808113
# Epoch 2 - loss: 0.0025324171874672174
# Epoch 2 - loss: 0.0099981389939785
# Epoch 2 - loss: 0.0004547502030618489
# Epoch 2 - loss: 0.0016388586955145001
# Epoch 2 - loss: 0.03211218863725662
# Epoch 2 - loss: 0.024577684700489044
# Epoch 3 - loss: 0.034798040986061096
# Epoch 3 - loss: 0.055402252823114395
# Epoch 3 - loss: 0.0024311526212841272
# Epoch 3 - loss: 0.000175155044416897
# Epoch 3 - loss: 0.02045578695833683
# Epoch 3 - loss: 0.005537122022360563
# Epoch 3 - loss: 0.0036107872147113085
# Epoch 3 - loss: 0.004240231588482857
# Epoch 3 - loss: 0.013204610906541348
# Epoch 3 - loss: 0.04530201107263565
# Epoch 4 - loss: 0.002073389943689108
# Epoch 4 - loss: 0.039207592606544495
# Epoch 4 - loss: 0.0001298869465244934
# Epoch 4 - loss: 0.0033021802082657814
# Epoch 4 - loss: 0.026841454207897186
# Epoch 4 - loss: 0.0003820485435426235
# Epoch 4 - loss: 0.003984157927334309
# Epoch 4 - loss: 0.0038536335341632366
# Epoch 4 - loss: 0.006160009186714888
# Epoch 4 - loss: 0.0378461629152298

# %%
network.eval()
z_pred = network(x_test.float())
after_train = criterion(z_pred.squeeze(), z_test.float())
print('Test loss after Training', after_train.item())
# Out:
# Test loss after Training 0.033961206674575806

# %%
z_test_pred = network.forward(x_test.float())

x_test = x_test.detach().numpy()
z_test_pred = z_test_pred.detach().numpy()

xs = x_test[:,0]
ys = x_test[:,1]
zs = z_test_pred

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs, ys, zs, c='r', marker = '.')
