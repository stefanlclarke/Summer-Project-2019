# %%
#This code produces a representation for each digit in 0, 1, 2, ..., 9 in some other lower
#dimensional space, where it must draw from Gaussian distributions. If you run the code to the
#end you will see that the recreated digits are quite blurry.


import numpy as np
import torch
from torch.autograd import Variable
from matplotlib import pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
import random
from PIL import Image

import torchvision
import torchvision.datasets as datasets
mnist_trainset = datasets.MNIST(root='./data', train=True, download=True, transform=None)
mnist_testset = datasets.MNIST(root='./data', train=False, download=True, transform=None)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to ./data\MNIST\raw\train-images-idx3-ubyte.gz
# 9920512it [00:06, 1640506.51it/s]
# Extracting ./data\MNIST\raw\train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to ./data\MNIST\raw\train-labels-idx1-ubyte.gz
# 32768it [00:00, 111931.82it/s]
# Extracting ./data\MNIST\raw\train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to ./data\MNIST\raw\t10k-images-idx3-ubyte.gz
# 1654784it [00:01, 1050578.23it/s]
# Extracting ./data\MNIST\raw\t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to ./data\MNIST\raw\t10k-labels-idx1-ubyte.gz
# 8192it [00:00, 41080.31it/s]
# Extracting ./data\MNIST\raw\t10k-labels-idx1-ubyte.gz
# Processing...
# Done!

# %%
def img_to_vector(imgs):
    data = [np.asarray(img, dtype="int32").reshape(28*28, 1) for img in imgs]
    return np.array(data)

# %%
mnist_trainset_images = [mnist_trainset[i][0] for i in range(len(mnist_trainset))]
mnist_trainset_digits = [mnist_trainset[i][1] for i in range(len(mnist_trainset))]

# %%
mnist_trainset_arrays = img_to_vector(mnist_trainset_images)*1/256

# %%
data = mnist_trainset_arrays

# %%
input_size = 28*28
encoded_size=100

class VAE(nn.Module):
    
    def __init__(self):
        super(VAE, self).__init__()
        self.e = nn.Linear(input_size, 100)
        self.e_mean = nn.Linear(100, encoded_size)
        self.e_logvar = nn.Linear(100, encoded_size)
        self.d1 = nn.Linear(encoded_size, 100)
        self.d2 = nn.Linear(100, input_size)
        self.relu = nn.ReLU()
        self.sigmoid = nn.Sigmoid()
        
    def en(self, x):
        mean = self.e_mean(self.relu(self.e(x)))
        logvar = self.e_logvar(self.relu(self.e(x)))
        return mean, logvar
    
    def sample(self, mean, logvar):
        std = torch.exp(0.5*logvar)
        eps = torch.randn_like(std)
        return mean + eps*std
    
    def de(self, z):
        output = self.sigmoid(self.d2(self.relu(self.d1(z))))
        return output
    
    def forward(self, x):
        mu, logvar = self.en(x)
        z = self.sample(mu, logvar)
        result = self.de(z)
        return result, mu, logvar

# %%
model = VAE()
optimizer = torch.optim.Adam(model.parameters(), lr=1e-3)

# %%
def lossf(newx, x, mu, logvar):
    BCE = F.binary_cross_entropy(newx, x.view(-1, input_size), reduction = 'sum')
    KLD = -0.5*torch.sum(1 + logvar - mu.pow(2) - logvar.exp())
    return BCE + KLD

def train(epochs):
    for epoch in range(epochs):
        t=0
        model.train()
        train_loss = 0
        for point in data:
            t+=1
            optimizer.zero_grad()
            point = Variable(torch.tensor(point.T).float())
            newpoint, mu, logvar = model(point)
            loss = lossf(newpoint, point.detach(), mu, logvar)
            loss.backward()
            train_loss += loss.item()
            optimizer.step()
            if t % 100 == 0:
                print('{}/60000 done for epoch {}'.format(t, epoch))
        print('EPOCH: {} LOSS {}'.format(epoch, train_loss))

# %%
train(1)
# Out:
# 100/60000 done for epoch 0
# 200/60000 done for epoch 0
# 300/60000 done for epoch 0
# 400/60000 done for epoch 0
# 500/60000 done for epoch 0
# 600/60000 done for epoch 0
# 700/60000 done for epoch 0
# 800/60000 done for epoch 0
# 900/60000 done for epoch 0
# 1000/60000 done for epoch 0
# 1100/60000 done for epoch 0
# 1200/60000 done for epoch 0
# 1300/60000 done for epoch 0
# 1400/60000 done for epoch 0
# 1500/60000 done for epoch 0
# 1600/60000 done for epoch 0
# 1700/60000 done for epoch 0
# 1800/60000 done for epoch 0
# 1900/60000 done for epoch 0
# 2000/60000 done for epoch 0
# 2100/60000 done for epoch 0
# 2200/60000 done for epoch 0
# 2300/60000 done for epoch 0
# 2400/60000 done for epoch 0
# 2500/60000 done for epoch 0
# 2600/60000 done for epoch 0
# 2700/60000 done for epoch 0
# 2800/60000 done for epoch 0
# 2900/60000 done for epoch 0
# 3000/60000 done for epoch 0
# 3100/60000 done for epoch 0
# 3200/60000 done for epoch 0
# 3300/60000 done for epoch 0
# 3400/60000 done for epoch 0
# 3500/60000 done for epoch 0
# 3600/60000 done for epoch 0
# 3700/60000 done for epoch 0
# 3800/60000 done for epoch 0
# 3900/60000 done for epoch 0
# 4000/60000 done for epoch 0
# 4100/60000 done for epoch 0
# 4200/60000 done for epoch 0
# 4300/60000 done for epoch 0
# 4400/60000 done for epoch 0
# 4500/60000 done for epoch 0
# 4600/60000 done for epoch 0
# 4700/60000 done for epoch 0
# 4800/60000 done for epoch 0
# 4900/60000 done for epoch 0
# 5000/60000 done for epoch 0
# 5100/60000 done for epoch 0
# 5200/60000 done for epoch 0
# 5300/60000 done for epoch 0
# 5400/60000 done for epoch 0
# 5500/60000 done for epoch 0
# 5600/60000 done for epoch 0
# 5700/60000 done for epoch 0
# 5800/60000 done for epoch 0
# 5900/60000 done for epoch 0
# 6000/60000 done for epoch 0
# 6100/60000 done for epoch 0
# 6200/60000 done for epoch 0
# 6300/60000 done for epoch 0
# 6400/60000 done for epoch 0
# 6500/60000 done for epoch 0
# 6600/60000 done for epoch 0
# 6700/60000 done for epoch 0
# 6800/60000 done for epoch 0
# 6900/60000 done for epoch 0
# 7000/60000 done for epoch 0
# 7100/60000 done for epoch 0
# 7200/60000 done for epoch 0
# 7300/60000 done for epoch 0
# 7400/60000 done for epoch 0
# 7500/60000 done for epoch 0
# 7600/60000 done for epoch 0
# 7700/60000 done for epoch 0
# 7800/60000 done for epoch 0
# 7900/60000 done for epoch 0
# 8000/60000 done for epoch 0
# 8100/60000 done for epoch 0
# 8200/60000 done for epoch 0
# 8300/60000 done for epoch 0
# 8400/60000 done for epoch 0
# 8500/60000 done for epoch 0
# 8600/60000 done for epoch 0
# 8700/60000 done for epoch 0
# 8800/60000 done for epoch 0
# 8900/60000 done for epoch 0
# 9000/60000 done for epoch 0
# 9100/60000 done for epoch 0
# 9200/60000 done for epoch 0
# 9300/60000 done for epoch 0
# 9400/60000 done for epoch 0
# 9500/60000 done for epoch 0
# 9600/60000 done for epoch 0
# 9700/60000 done for epoch 0
# 9800/60000 done for epoch 0
# 9900/60000 done for epoch 0
# 10000/60000 done for epoch 0
# 10100/60000 done for epoch 0
# 10200/60000 done for epoch 0
# 10300/60000 done for epoch 0
# 10400/60000 done for epoch 0
# 10500/60000 done for epoch 0
# 10600/60000 done for epoch 0
# 10700/60000 done for epoch 0
# 10800/60000 done for epoch 0
# 10900/60000 done for epoch 0
# 11000/60000 done for epoch 0
# 11100/60000 done for epoch 0
# 11200/60000 done for epoch 0
# 11300/60000 done for epoch 0
# 11400/60000 done for epoch 0
# 11500/60000 done for epoch 0
# 11600/60000 done for epoch 0
# 11700/60000 done for epoch 0
# 11800/60000 done for epoch 0
# 11900/60000 done for epoch 0
# 12000/60000 done for epoch 0
# 12100/60000 done for epoch 0
# 12200/60000 done for epoch 0
# 12300/60000 done for epoch 0
# 12400/60000 done for epoch 0
# 12500/60000 done for epoch 0
# 12600/60000 done for epoch 0
# 12700/60000 done for epoch 0
# 12800/60000 done for epoch 0
# 12900/60000 done for epoch 0
# 13000/60000 done for epoch 0
# 13100/60000 done for epoch 0
# 13200/60000 done for epoch 0
# 13300/60000 done for epoch 0
# 13400/60000 done for epoch 0
# 13500/60000 done for epoch 0
# 13600/60000 done for epoch 0
# 13700/60000 done for epoch 0
# 13800/60000 done for epoch 0
# 13900/60000 done for epoch 0
# 14000/60000 done for epoch 0
# 14100/60000 done for epoch 0
# 14200/60000 done for epoch 0
# 14300/60000 done for epoch 0
# 14400/60000 done for epoch 0
# 14500/60000 done for epoch 0
# 14600/60000 done for epoch 0
# 14700/60000 done for epoch 0
# 14800/60000 done for epoch 0
# 14900/60000 done for epoch 0
# 15000/60000 done for epoch 0
# 15100/60000 done for epoch 0
# 15200/60000 done for epoch 0
# 15300/60000 done for epoch 0
# 15400/60000 done for epoch 0
# 15500/60000 done for epoch 0
# 15600/60000 done for epoch 0
# 15700/60000 done for epoch 0
# 15800/60000 done for epoch 0
# 15900/60000 done for epoch 0
# 16000/60000 done for epoch 0
# 16100/60000 done for epoch 0
# 16200/60000 done for epoch 0
# 16300/60000 done for epoch 0
# 16400/60000 done for epoch 0
# 16500/60000 done for epoch 0
# 16600/60000 done for epoch 0
# 16700/60000 done for epoch 0
# 16800/60000 done for epoch 0
# 16900/60000 done for epoch 0
# 17000/60000 done for epoch 0
# 17100/60000 done for epoch 0
# 17200/60000 done for epoch 0
# 17300/60000 done for epoch 0
# 17400/60000 done for epoch 0
# 17500/60000 done for epoch 0
# 17600/60000 done for epoch 0
# 17700/60000 done for epoch 0
# 17800/60000 done for epoch 0
# 17900/60000 done for epoch 0
# 18000/60000 done for epoch 0
# 18100/60000 done for epoch 0
# 18200/60000 done for epoch 0
# 18300/60000 done for epoch 0
# 18400/60000 done for epoch 0
# 18500/60000 done for epoch 0
# 18600/60000 done for epoch 0
# 18700/60000 done for epoch 0
# 18800/60000 done for epoch 0
# 18900/60000 done for epoch 0
# 19000/60000 done for epoch 0
# 19100/60000 done for epoch 0
# 19200/60000 done for epoch 0
# 19300/60000 done for epoch 0
# 19400/60000 done for epoch 0
# 19500/60000 done for epoch 0
# 19600/60000 done for epoch 0
# 19700/60000 done for epoch 0
# 19800/60000 done for epoch 0
# 19900/60000 done for epoch 0
# 20000/60000 done for epoch 0
# 20100/60000 done for epoch 0
# 20200/60000 done for epoch 0
# 20300/60000 done for epoch 0
# 20400/60000 done for epoch 0
# 20500/60000 done for epoch 0
# 20600/60000 done for epoch 0
# 20700/60000 done for epoch 0
# 20800/60000 done for epoch 0
# 20900/60000 done for epoch 0
# 21000/60000 done for epoch 0
# 21100/60000 done for epoch 0
# 21200/60000 done for epoch 0
# 21300/60000 done for epoch 0
# 21400/60000 done for epoch 0
# 21500/60000 done for epoch 0
# 21600/60000 done for epoch 0
# 21700/60000 done for epoch 0
# 21800/60000 done for epoch 0
# 21900/60000 done for epoch 0
# 22000/60000 done for epoch 0
# 22100/60000 done for epoch 0
# 22200/60000 done for epoch 0
# 22300/60000 done for epoch 0
# 22400/60000 done for epoch 0
# 22500/60000 done for epoch 0
# 22600/60000 done for epoch 0
# 22700/60000 done for epoch 0
# 22800/60000 done for epoch 0
# 22900/60000 done for epoch 0
# 23000/60000 done for epoch 0
# 23100/60000 done for epoch 0
# 23200/60000 done for epoch 0
# 23300/60000 done for epoch 0
# 23400/60000 done for epoch 0
# 23500/60000 done for epoch 0
# 23600/60000 done for epoch 0
# 23700/60000 done for epoch 0
# 23800/60000 done for epoch 0
# 23900/60000 done for epoch 0
# 24000/60000 done for epoch 0
# 24100/60000 done for epoch 0
# 24200/60000 done for epoch 0
# 24300/60000 done for epoch 0
# 24400/60000 done for epoch 0
# 24500/60000 done for epoch 0
# 24600/60000 done for epoch 0
# 24700/60000 done for epoch 0
# 24800/60000 done for epoch 0
# 24900/60000 done for epoch 0
# 25000/60000 done for epoch 0
# 25100/60000 done for epoch 0
# 25200/60000 done for epoch 0
# 25300/60000 done for epoch 0
# 25400/60000 done for epoch 0
# 25500/60000 done for epoch 0
# 25600/60000 done for epoch 0
# 25700/60000 done for epoch 0
# 25800/60000 done for epoch 0
# 25900/60000 done for epoch 0
# 26000/60000 done for epoch 0
# 26100/60000 done for epoch 0
# 26200/60000 done for epoch 0
# 26300/60000 done for epoch 0
# 26400/60000 done for epoch 0
# 26500/60000 done for epoch 0
# 26600/60000 done for epoch 0
# 26700/60000 done for epoch 0
# 26800/60000 done for epoch 0
# 26900/60000 done for epoch 0
# 27000/60000 done for epoch 0
# 27100/60000 done for epoch 0
# 27200/60000 done for epoch 0
# 27300/60000 done for epoch 0
# 27400/60000 done for epoch 0
# 27500/60000 done for epoch 0
# 27600/60000 done for epoch 0
# 27700/60000 done for epoch 0
# 27800/60000 done for epoch 0
# 27900/60000 done for epoch 0
# 28000/60000 done for epoch 0
# 28100/60000 done for epoch 0
# 28200/60000 done for epoch 0
# 28300/60000 done for epoch 0
# 28400/60000 done for epoch 0
# 28500/60000 done for epoch 0
# 28600/60000 done for epoch 0
# 28700/60000 done for epoch 0
# 28800/60000 done for epoch 0
# 28900/60000 done for epoch 0
# 29000/60000 done for epoch 0
# 29100/60000 done for epoch 0
# 29200/60000 done for epoch 0
# 29300/60000 done for epoch 0
# 29400/60000 done for epoch 0
# 29500/60000 done for epoch 0
# 29600/60000 done for epoch 0
# 29700/60000 done for epoch 0
# 29800/60000 done for epoch 0
# 29900/60000 done for epoch 0
# 30000/60000 done for epoch 0
# 30100/60000 done for epoch 0
# 30200/60000 done for epoch 0
# 30300/60000 done for epoch 0
# 30400/60000 done for epoch 0
# 30500/60000 done for epoch 0
# 30600/60000 done for epoch 0
# 30700/60000 done for epoch 0
# 30800/60000 done for epoch 0
# 30900/60000 done for epoch 0
# 31000/60000 done for epoch 0
# 31100/60000 done for epoch 0
# 31200/60000 done for epoch 0
# 31300/60000 done for epoch 0
# 31400/60000 done for epoch 0
# 31500/60000 done for epoch 0
# 31600/60000 done for epoch 0
# 31700/60000 done for epoch 0
# 31800/60000 done for epoch 0
# 31900/60000 done for epoch 0
# 32000/60000 done for epoch 0
# 32100/60000 done for epoch 0
# 32200/60000 done for epoch 0
# 32300/60000 done for epoch 0
# 32400/60000 done for epoch 0
# 32500/60000 done for epoch 0
# 32600/60000 done for epoch 0
# 32700/60000 done for epoch 0
# 32800/60000 done for epoch 0
# 32900/60000 done for epoch 0
# 33000/60000 done for epoch 0
# 33100/60000 done for epoch 0
# 33200/60000 done for epoch 0
# 33300/60000 done for epoch 0
# 33400/60000 done for epoch 0
# 33500/60000 done for epoch 0
# 33600/60000 done for epoch 0
# 33700/60000 done for epoch 0
# 33800/60000 done for epoch 0
# 33900/60000 done for epoch 0
# 34000/60000 done for epoch 0
# 34100/60000 done for epoch 0
# 34200/60000 done for epoch 0
# 34300/60000 done for epoch 0
# 34400/60000 done for epoch 0
# 34500/60000 done for epoch 0
# 34600/60000 done for epoch 0
# 34700/60000 done for epoch 0
# 34800/60000 done for epoch 0
# 34900/60000 done for epoch 0
# 35000/60000 done for epoch 0
# 35100/60000 done for epoch 0
# 35200/60000 done for epoch 0
# 35300/60000 done for epoch 0
# 35400/60000 done for epoch 0
# 35500/60000 done for epoch 0
# 35600/60000 done for epoch 0
# 35700/60000 done for epoch 0
# 35800/60000 done for epoch 0
# 35900/60000 done for epoch 0
# 36000/60000 done for epoch 0
# 36100/60000 done for epoch 0
# 36200/60000 done for epoch 0
# 36300/60000 done for epoch 0
# 36400/60000 done for epoch 0
# 36500/60000 done for epoch 0
# 36600/60000 done for epoch 0
# 36700/60000 done for epoch 0
# 36800/60000 done for epoch 0
# 36900/60000 done for epoch 0
# 37000/60000 done for epoch 0
# 37100/60000 done for epoch 0
# 37200/60000 done for epoch 0
# 37300/60000 done for epoch 0
# 37400/60000 done for epoch 0
# 37500/60000 done for epoch 0
# 37600/60000 done for epoch 0
# 37700/60000 done for epoch 0
# 37800/60000 done for epoch 0
# 37900/60000 done for epoch 0
# 38000/60000 done for epoch 0
# 38100/60000 done for epoch 0
# 38200/60000 done for epoch 0
# 38300/60000 done for epoch 0
# 38400/60000 done for epoch 0
# 38500/60000 done for epoch 0
# 38600/60000 done for epoch 0
# 38700/60000 done for epoch 0
# 38800/60000 done for epoch 0
# 38900/60000 done for epoch 0
# 39000/60000 done for epoch 0
# 39100/60000 done for epoch 0
# 39200/60000 done for epoch 0
# 39300/60000 done for epoch 0
# 39400/60000 done for epoch 0
# 39500/60000 done for epoch 0
# 39600/60000 done for epoch 0
# 39700/60000 done for epoch 0
# 39800/60000 done for epoch 0
# 39900/60000 done for epoch 0
# 40000/60000 done for epoch 0
# 40100/60000 done for epoch 0
# 40200/60000 done for epoch 0
# 40300/60000 done for epoch 0
# 40400/60000 done for epoch 0
# 40500/60000 done for epoch 0
# 40600/60000 done for epoch 0
# 40700/60000 done for epoch 0
# 40800/60000 done for epoch 0
# 40900/60000 done for epoch 0
# 41000/60000 done for epoch 0
# 41100/60000 done for epoch 0
# 41200/60000 done for epoch 0
# 41300/60000 done for epoch 0
# 41400/60000 done for epoch 0
# 41500/60000 done for epoch 0
# 41600/60000 done for epoch 0
# 41700/60000 done for epoch 0
# 41800/60000 done for epoch 0
# 41900/60000 done for epoch 0
# 42000/60000 done for epoch 0
# 42100/60000 done for epoch 0
# 42200/60000 done for epoch 0
# 42300/60000 done for epoch 0
# 42400/60000 done for epoch 0
# 42500/60000 done for epoch 0
# 42600/60000 done for epoch 0
# 42700/60000 done for epoch 0
# 42800/60000 done for epoch 0
# 42900/60000 done for epoch 0
# 43000/60000 done for epoch 0
# 43100/60000 done for epoch 0
# 43200/60000 done for epoch 0
# 43300/60000 done for epoch 0
# 43400/60000 done for epoch 0
# 43500/60000 done for epoch 0
# 43600/60000 done for epoch 0
# 43700/60000 done for epoch 0
# 43800/60000 done for epoch 0
# 43900/60000 done for epoch 0
# 44000/60000 done for epoch 0
# 44100/60000 done for epoch 0
# 44200/60000 done for epoch 0
# 44300/60000 done for epoch 0
# 44400/60000 done for epoch 0
# 44500/60000 done for epoch 0
# 44600/60000 done for epoch 0
# 44700/60000 done for epoch 0
# 44800/60000 done for epoch 0
# 44900/60000 done for epoch 0
# 45000/60000 done for epoch 0
# 45100/60000 done for epoch 0
# 45200/60000 done for epoch 0
# 45300/60000 done for epoch 0
# 45400/60000 done for epoch 0
# 45500/60000 done for epoch 0
# 45600/60000 done for epoch 0
# 45700/60000 done for epoch 0
# 45800/60000 done for epoch 0
# 45900/60000 done for epoch 0
# 46000/60000 done for epoch 0
# 46100/60000 done for epoch 0
# 46200/60000 done for epoch 0
# 46300/60000 done for epoch 0
# 46400/60000 done for epoch 0
# 46500/60000 done for epoch 0
# 46600/60000 done for epoch 0
# 46700/60000 done for epoch 0
# 46800/60000 done for epoch 0
# 46900/60000 done for epoch 0
# 47000/60000 done for epoch 0
# 47100/60000 done for epoch 0
# 47200/60000 done for epoch 0
# 47300/60000 done for epoch 0
# 47400/60000 done for epoch 0
# 47500/60000 done for epoch 0
# 47600/60000 done for epoch 0
# 47700/60000 done for epoch 0
# 47800/60000 done for epoch 0
# 47900/60000 done for epoch 0
# 48000/60000 done for epoch 0
# 48100/60000 done for epoch 0
# 48200/60000 done for epoch 0
# 48300/60000 done for epoch 0
# 48400/60000 done for epoch 0
# 48500/60000 done for epoch 0
# 48600/60000 done for epoch 0
# 48700/60000 done for epoch 0
# 48800/60000 done for epoch 0
# 48900/60000 done for epoch 0
# 49000/60000 done for epoch 0
# 49100/60000 done for epoch 0
# 49200/60000 done for epoch 0
# 49300/60000 done for epoch 0
# 49400/60000 done for epoch 0
# 49500/60000 done for epoch 0
# 49600/60000 done for epoch 0
# 49700/60000 done for epoch 0
# 49800/60000 done for epoch 0
# 49900/60000 done for epoch 0
# 50000/60000 done for epoch 0
# 50100/60000 done for epoch 0
# 50200/60000 done for epoch 0
# 50300/60000 done for epoch 0
# 50400/60000 done for epoch 0
# 50500/60000 done for epoch 0
# 50600/60000 done for epoch 0
# 50700/60000 done for epoch 0
# 50800/60000 done for epoch 0
# 50900/60000 done for epoch 0
# 51000/60000 done for epoch 0
# 51100/60000 done for epoch 0
# 51200/60000 done for epoch 0
# 51300/60000 done for epoch 0
# 51400/60000 done for epoch 0
# 51500/60000 done for epoch 0
# 51600/60000 done for epoch 0
# 51700/60000 done for epoch 0
# 51800/60000 done for epoch 0
# 51900/60000 done for epoch 0
# 52000/60000 done for epoch 0
# 52100/60000 done for epoch 0
# 52200/60000 done for epoch 0
# 52300/60000 done for epoch 0
# 52400/60000 done for epoch 0
# 52500/60000 done for epoch 0
# 52600/60000 done for epoch 0
# 52700/60000 done for epoch 0
# 52800/60000 done for epoch 0
# 52900/60000 done for epoch 0
# 53000/60000 done for epoch 0
# 53100/60000 done for epoch 0
# 53200/60000 done for epoch 0
# 53300/60000 done for epoch 0
# 53400/60000 done for epoch 0
# 53500/60000 done for epoch 0
# 53600/60000 done for epoch 0
# 53700/60000 done for epoch 0
# 53800/60000 done for epoch 0
# 53900/60000 done for epoch 0
# 54000/60000 done for epoch 0
# 54100/60000 done for epoch 0
# 54200/60000 done for epoch 0
# 54300/60000 done for epoch 0
# 54400/60000 done for epoch 0
# 54500/60000 done for epoch 0
# 54600/60000 done for epoch 0
# 54700/60000 done for epoch 0
# 54800/60000 done for epoch 0
# 54900/60000 done for epoch 0
# 55000/60000 done for epoch 0
# 55100/60000 done for epoch 0
# 55200/60000 done for epoch 0
# 55300/60000 done for epoch 0
# 55400/60000 done for epoch 0
# 55500/60000 done for epoch 0
# 55600/60000 done for epoch 0
# 55700/60000 done for epoch 0
# 55800/60000 done for epoch 0
# 55900/60000 done for epoch 0
# 56000/60000 done for epoch 0
# 56100/60000 done for epoch 0
# 56200/60000 done for epoch 0
# 56300/60000 done for epoch 0
# 56400/60000 done for epoch 0
# 56500/60000 done for epoch 0
# 56600/60000 done for epoch 0
# 56700/60000 done for epoch 0
# 56800/60000 done for epoch 0
# 56900/60000 done for epoch 0
# 57000/60000 done for epoch 0
# 57100/60000 done for epoch 0
# 57200/60000 done for epoch 0
# 57300/60000 done for epoch 0
# 57400/60000 done for epoch 0
# 57500/60000 done for epoch 0
# 57600/60000 done for epoch 0
# 57700/60000 done for epoch 0
# 57800/60000 done for epoch 0
# 57900/60000 done for epoch 0
# 58000/60000 done for epoch 0
# 58100/60000 done for epoch 0
# 58200/60000 done for epoch 0
# 58300/60000 done for epoch 0
# 58400/60000 done for epoch 0
# 58500/60000 done for epoch 0
# 58600/60000 done for epoch 0
# 58700/60000 done for epoch 0
# 58800/60000 done for epoch 0
# 58900/60000 done for epoch 0
# 59000/60000 done for epoch 0
# 59100/60000 done for epoch 0
# 59200/60000 done for epoch 0
# 59300/60000 done for epoch 0
# 59400/60000 done for epoch 0
# 59500/60000 done for epoch 0
# 59600/60000 done for epoch 0
# 59700/60000 done for epoch 0
# 59800/60000 done for epoch 0
# 59900/60000 done for epoch 0
# 60000/60000 done for epoch 0
# EPOCH: 0 LOSS 7571999.206520081

# %%
def get_image(vector):
    img_array = (vector.reshape(28, 28)*256).astype(int)
    img = Image.fromarray(img_array)
    img.show()

# %%
im = torch.tensor(mnist_trainset_arrays[1].T).float()
newdigit = model(im)
newdigit_np = newdigit[0].detach().numpy()
get_image(newdigit_np)
